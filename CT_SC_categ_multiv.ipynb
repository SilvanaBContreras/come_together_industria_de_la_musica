# %% [markdown]
# # Análisis multivariado descriptivo de variables categóricas

# %% [markdown]
# ## 0. Setup

# %%
# %pip install lightgbm optuna

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
import pathlib
warnings.filterwarnings('ignore')

from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

plt.rcParams['figure.dpi'] = 110

print('Imports OK')
# Out:
# Imports OK

# %%
from pathlib import Path

# ============================================================
# Directorio único de guardado de gráficos y tablas del proyecto
# ============================================================

directorio_salidas_proyecto = Path(
    r"C:\Users\Silvana\Documents\Maestria_Exactas\taller_tesis_1\music_industry_social_live_code\graficos"
)

directorio_salidas_proyecto.mkdir(
    parents=True,
    exist_ok=True
)

print("Directorio de salida:", directorio_salidas_proyecto)
print("Existe:", directorio_salidas_proyecto.exists())
# Out:
# Directorio de salida: C:\Users\Silvana\Documents\Maestria_Exactas\taller_tesis_1\music_industry_social_live_code\graficos
# Existe: True

# %% [markdown]
# ## 1. Carga de datos

# %%
#df = pd.read_csv('dataset_7000_53.csv')

df = pd.read_csv("dataset_4913_53.csv") #dataset con target sin NA

print(f'Shape: {df.shape}')
print(f"n_shows_24_25 — con dato: {df['n_shows_24_25'].notna().sum()}  "
      f"sin dato: {df['n_shows_24_25'].isna().sum()}")
df[['artist_name','sp_monthly_listeners','ins_followers','n_shows_24_25']].head(3)
# Out:
# Shape: (4913, 53)
# n_shows_24_25 — con dato: 4913  sin dato: 0
#     artist_name  sp_monthly_listeners  ins_followers  n_shows_24_25
# 0     Bad Bunny           112734492.0     54721804.0             45
# 1  Taylor Swift           102733014.0    280531827.0             49
# 2    Bruno Mars           134166866.0     42922145.0             55

# %% [markdown]
# # dimensiones variables

# %%
# Agrupación conceptual de variables
# Construcción de diccionario de variables

id_cols = [
    "chartmetric_id",
    "artist_name"
]

metadata_cols = [
    "country",
    "country_short",
    "pronoun_title",
    "pronoun_short",
    "record_label",
    "major_record_label",
    "primary_genre",
    "genre_short",
    "band",
    "muerto_disuelto"
]

streaming_cols = [
    "sp_followers",
    "sp_monthly_listeners",
    "sp_popularity",
    "deezer_fans",
    "shazam_count",
    "pandora_lifetime_streams",
    "pandora_lifetime_stations_added"
]

playlist_cols = [
    "sp_playlist_total_reach",
    "num_sp_editorial_playlists",
    "num_sp_playlists",
    "sp_editorial_playlist_total_reach",
    "num_am_editorial_playlists",
    "num_am_playlists",
    "num_de_editorial_playlists",
    "num_de_playlists",
    "de_playlist_total_reach",
    "de_editorial_playlist_total_reach",
    "num_az_editorial_playlists",
    "num_az_playlists",
    "num_yt_editorial_playlists",
    "num_yt_playlists",
    "yt_playlist_total_reach"
]

social_cols = [
    "ins_followers",
    "twitter_followers",
    "tiktok_followers",
    "tiktok_likes",
    "tiktok_top_video_views",
    "tiktok_top_video_comments",
    "tiktok_track_posts"
]

youtube_cols = [
    "ycs_subscribers",
    "ycs_views",
    "youtube_daily_video_views",
    "youtube_monthly_video_views"
]

live_cols = [
    "n_shows_24_25",
    "n_shows_with_capacity_24_25",
    "capacity_24_25",
    "avg_venue_capacity_24_25",
    "n_cities_24_25",
    "n_countries_24_25",
    "shows_per_country_24_25",
    "off_cycle"
]


# Diccionario de dimensiones
column_groups = {
    "identificacion": id_cols,
    "metadata": metadata_cols,
    "streaming": streaming_cols,
    "playlists": playlist_cols,
    "redes_sociales": social_cols,
    "youtube": youtube_cols,
    "live_events": live_cols
}

# ============================================================
# Tabla auxiliar con identidad conceptual de cada variable
# ============================================================

variable_dimension = []

for dimension, cols in column_groups.items():
    for col in cols:
        variable_dimension.append({
            "variable": col,
            "dimension": dimension
        })

df_variable_dimension = pd.DataFrame(variable_dimension)

# ============================================================
# Control de cobertura de columnas
# ============================================================

grouped_cols = df_variable_dimension["variable"].tolist()

cols_in_groups_not_in_df = sorted(set(grouped_cols) - set(df.columns))
cols_in_df_not_in_groups = sorted(set(df.columns) - set(grouped_cols))

print("Columnas del df:", df.shape[1])
print("Columnas agrupadas:", len(grouped_cols))
print("Columnas agrupadas que no están en df:", cols_in_groups_not_in_df)
print("Columnas del df no agrupadas:", cols_in_df_not_in_groups)

# ============================================================
# Resumen por dimensión
# ============================================================

resumen_dimensiones = (
    df_variable_dimension
    .groupby("dimension", as_index=False)
    .agg(n_variables=("variable", "count"))
    .sort_values("n_variables", ascending=False)
)

display(resumen_dimensiones)

# ============================================================
# Vista del diccionario de variables
# ============================================================

display(df_variable_dimension)
# Out:
# Columnas del df: 53
# Columnas agrupadas: 53
# Columnas agrupadas que no están en df: []
# Columnas del df no agrupadas: []
#         dimension  n_variables
# 3       playlists           15
# 2        metadata           10
# 1     live_events            8
# 5       streaming            7
# 4  redes_sociales            7
# 6         youtube            4
# 0  identificacion            2
#                              variable       dimension
# 0                      chartmetric_id  identificacion
# 1                         artist_name  identificacion
# 2                             country        metadata
# 3                       country_short        metadata
# 4                       pronoun_title        metadata
# 5                       pronoun_short        metadata
# 6                        record_label        metadata
# 7                  major_record_label        metadata
# 8                       primary_genre        metadata
# 9                         genre_short        metadata
# 10                               band        metadata
# 11                    muerto_disuelto        metadata
# 12                       sp_followers       streaming
# 13               sp_monthly_listeners       streaming
# 14                      sp_popularity       streaming
# 15                        deezer_fans       streaming
# 16                       shazam_count       streaming
# 17           pandora_lifetime_streams       streaming
# 18    pandora_lifetime_stations_added       streaming
# 19            sp_playlist_total_reach       playlists
# 20         num_sp_editorial_playlists       playlists
# 21                   num_sp_playlists       playlists
# 22  sp_editorial_playlist_total_reach       playlists
# 23         num_am_editorial_playlists       playlists
# 24                   num_am_playlists       playlists
# 25         num_de_editorial_playlists       playlists
# 26                   num_de_playlists       playlists
# 27            de_playlist_total_reach       playlists
# 28  de_editorial_playlist_total_reach       playlists
# 29         num_az_editorial_playlists       playlists
# 30                   num_az_playlists       playlists
# 31         num_yt_editorial_playlists       playlists
# 32                   num_yt_playlists       playlists
# 33            yt_playlist_total_reach       playlists
# 34                      ins_followers  redes_sociales
# 35                  twitter_followers  redes_sociales
# 36                   tiktok_followers  redes_sociales
# 37                       tiktok_likes  redes_sociales
# 38             tiktok_top_video_views  redes_sociales
# 39          tiktok_top_video_comments  redes_sociales
# 40                 tiktok_track_posts  redes_sociales
# 41                    ycs_subscribers         youtube
# 42                          ycs_views         youtube
# 43          youtube_daily_video_views         youtube
# 44        youtube_monthly_video_views         youtube
# 45                      n_shows_24_25     live_events
# 46        n_shows_with_capacity_24_25     live_events
# 47                     capacity_24_25     live_events
# 48           avg_venue_capacity_24_25     live_events
# 49                     n_cities_24_25     live_events
# 50                  n_countries_24_25     live_events
# 51            shows_per_country_24_25     live_events
# 52                          off_cycle     live_events

# %% [markdown]
# # tipos datos

# %%
# 1. Definir el diccionario de tipos

# agregar los ratios en el diccionario

dtypes_dict = {
    'chartmetric_id': 'Int64',
    'artist_name': 'str',
    'country': 'category',
    'pronoun_title': 'category',
    'record_label': 'category',
    'primary_genre': 'category',
    'sp_followers': 'Int64',
    'sp_monthly_listeners': 'Int64',
    'sp_popularity': 'float64',
    'sp_playlist_total_reach': 'float64',
    'ins_followers': 'Int64',
    'twitter_followers': 'Int64',
    'tiktok_followers': 'Int64',
    'tiktok_likes': 'Int64',
    'ycs_subscribers': 'Int64',
    'ycs_views': 'Int64',
    'youtube_daily_video_views': 'Int64',
    'youtube_monthly_video_views': 'Int64',
    'deezer_fans': 'Int64',
    'shazam_count': 'Int64',
    'pandora_lifetime_streams': 'Int64',
    'pandora_lifetime_stations_added': 'Int64',
    'band': 'bool',
    'num_sp_editorial_playlists': 'Int64',
    'num_sp_playlists': 'Int64',
    'sp_editorial_playlist_total_reach': 'float64',
    'num_am_editorial_playlists': 'Int64',
    'num_am_playlists': 'Int64',
    'num_de_editorial_playlists': 'Int64',
    'num_de_playlists': 'Int64',
    'de_playlist_total_reach': 'float64',
    'de_editorial_playlist_total_reach': 'float64',
    'num_az_editorial_playlists': 'Int64',
    'num_az_playlists': 'Int64',
    'num_yt_editorial_playlists': 'Int64',
    'num_yt_playlists': 'Int64',
    'yt_playlist_total_reach': 'float64',
    'tiktok_top_video_views': 'float64',
    'tiktok_top_video_comments': 'float64',
    'tiktok_track_posts': 'float64',
    'n_shows_24_25': 'Int64',
    'n_shows_with_capacity_24_25': 'Int64',
    'capacity_24_25': 'float64',
    'avg_venue_capacity_24_25': 'float64',
    'n_cities_24_25': 'Int64',
    'n_countries_24_25': 'Int64',
    'shows_per_country_24_25': 'float64',
    'major_record_label': 'boolean',
    'pronoun_short': 'category',
    'genre_short': 'category',
    'country_short': 'category',
    'off_cycle': 'bool',
    'muerto_disuelto': 'boolean'
}

# Aplicar la conversión al dataframe df

# Conversión solo de columnas existentes
dtypes_presentes = {
    col: dtype
    for col, dtype in dtypes_dict.items()
    if col in df.columns
}

df = df.astype(dtypes_presentes)

# 3. Verificación rápida
print(df.info())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4913 entries, 0 to 4912
# Data columns (total 53 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   chartmetric_id                     4913 non-null   Int64
#  1   artist_name                        4913 non-null   str
#  2   country                            4909 non-null   category
#  3   pronoun_title                      4913 non-null   category
#  4   record_label                       4604 non-null   category
#  5   primary_genre                      4913 non-null   category
#  6   sp_followers                       4907 non-null   Int64
#  7   sp_monthly_listeners               4907 non-null   Int64
#  8   sp_popularity                      4911 non-null   float64
#  9   sp_playlist_total_reach            4913 non-null   float64
#  10  ins_followers                      4580 non-null   Int64
#  11  twitter_followers                  3968 non-null   Int64
#  12  tiktok_followers                   3604 non-null   Int64
#  13  tiktok_likes                       3604 non-null   Int64
#  14  ycs_subscribers                    4670 non-null   Int64
#  15  ycs_views                          4670 non-null   Int64
#  16  youtube_daily_video_views          3401 non-null   Int64
#  17  youtube_monthly_video_views        3401 non-null   Int64
#  18  deezer_fans                        4853 non-null   Int64
#  19  shazam_count                       4912 non-null   Int64
#  20  pandora_lifetime_streams           4817 non-null   Int64
#  21  pandora_lifetime_stations_added    4764 non-null   Int64
#  22  band                               4913 non-null   bool
#  23  num_sp_editorial_playlists         4913 non-null   Int64
#  24  num_sp_playlists                   4913 non-null   Int64
#  25  sp_editorial_playlist_total_reach  4913 non-null   float64
#  26  num_am_editorial_playlists         4885 non-null   Int64
#  27  num_am_playlists                   4885 non-null   Int64
#  28  num_de_editorial_playlists         4811 non-null   Int64
#  29  num_de_playlists                   4811 non-null   Int64
#  30  de_playlist_total_reach            4811 non-null   float64
#  31  de_editorial_playlist_total_reach  4811 non-null   float64
#  32  num_az_editorial_playlists         4675 non-null   Int64
#  33  num_az_playlists                   4675 non-null   Int64
#  34  num_yt_editorial_playlists         4819 non-null   Int64
#  35  num_yt_playlists                   4819 non-null   Int64
#  36  yt_playlist_total_reach            4772 non-null   float64
#  37  tiktok_top_video_views             4905 non-null   float64
#  38  tiktok_top_video_comments          4905 non-null   float64
#  39  tiktok_track_posts                 4902 non-null   float64
#  40  n_shows_24_25                      4913 non-null   Int64
#  41  n_shows_with_capacity_24_25        4913 non-null   Int64
#  42  capacity_24_25                     4730 non-null   float64
#  43  avg_venue_capacity_24_25           3870 non-null   float64
#  44  n_cities_24_25                     4913 non-null   Int64
#  45  n_countries_24_25                  4913 non-null   Int64
#  46  shows_per_country_24_25            4025 non-null   float64
#  47  major_record_label                 4604 non-null   boolean
#  48  pronoun_short                      4913 non-null   category
#  49  genre_short                        4913 non-null   category
#  50  country_short                      4909 non-null   category
#  51  muerto_disuelto                    4690 non-null   boolean
#  52  off_cycle                          4913 non-null   bool
# dtypes: Int64(29), bool(2), boolean(2), category(7), float64(12), str(1)
# memory usage: 1.8 MB
# None

# %%
# Estructura general del dataset
print("Filas y columnas:", df.shape)

# Control de clave única
print("Artistas únicos:", df["chartmetric_id"].nunique())
print("Duplicados por chartmetric_id:", df.duplicated(subset="chartmetric_id").sum())

# Control de target
print("Nulos en target:", df["n_shows_24_25"].isna().sum())
print("Tipo de dato de target:", df["n_shows_24_25"].dtype)
# Out:
# Filas y columnas: (4913, 53)
# Artistas únicos: 4913
# Duplicados por chartmetric_id: 0
# Nulos en target: 0
# Tipo de dato de target: Int64

# %%
# ============================================================
# Parámetros del análisis categórico multivariado
# ============================================================

from itertools import combinations

target_shows = "n_shows_24_25"
target_log1p_shows = "log1p_n_shows_24_25"

variables_categoricas_candidatas = [
    "genre_short",
    "country_short",
    "major_record_label",
    "band",
    "pronoun_short"
]

umbral_minimo_artistas_por_celda = 20

directorio_tablas_categoricas = pathlib.Path("tablas_categoricas")
directorio_tablas_categoricas.mkdir(exist_ok=True)

df_categoricas_target = df.copy()

df_categoricas_target[target_log1p_shows] = np.log1p(
    df_categoricas_target[target_shows].astype(float)
)

for variable_categorica in variables_categoricas_candidatas:
    df_categoricas_target[variable_categorica] = (
        df_categoricas_target[variable_categorica]
        .astype("object")
        .where(df_categoricas_target[variable_categorica].notna(), "Sin dato")
        .astype(str)
    )

mediana_global_shows = df_categoricas_target[target_shows].median()
mediana_global_log1p_shows = df_categoricas_target[target_log1p_shows].median()
pct_global_cero_shows = (df_categoricas_target[target_shows].eq(0).mean() * 100)

print("Dataset de trabajo:", df_categoricas_target.shape)
print("Target:", target_shows)
print("Mediana global shows:", mediana_global_shows)
print("Mediana global log1p shows:", round(mediana_global_log1p_shows, 4))
print("Porcentaje global de ceros:", round(pct_global_cero_shows, 2))
# Out:
# Dataset de trabajo: (4913, 54)
# Target: n_shows_24_25
# Mediana global shows: 13.0
# Mediana global log1p shows: 2.6391
# Porcentaje global de ceros: 17.5

# %%
# ============================================================
# Sanity check de variables categóricas candidatas
# ============================================================

columnas_faltantes_categoricas = [
    variable_categorica
    for variable_categorica in variables_categoricas_candidatas
    if variable_categorica not in df_categoricas_target.columns
]

if len(columnas_faltantes_categoricas) > 0:
    raise ValueError(f"Columnas faltantes: {columnas_faltantes_categoricas}")

resumen_variables_categoricas = []

for variable_categorica in variables_categoricas_candidatas:
    resumen_variables_categoricas.append({
        "variable": variable_categorica,
        "n_categorias": df_categoricas_target[variable_categorica].nunique(),
        "n_sin_dato": (df_categoricas_target[variable_categorica] == "Sin dato").sum(),
        "pct_sin_dato": round(
            (df_categoricas_target[variable_categorica] == "Sin dato").mean() * 100,
            2
        )
    })

tabla_sanity_variables_categoricas = pd.DataFrame(resumen_variables_categoricas)

tabla_sanity_variables_categoricas
# Out:
#              variable  n_categorias  n_sin_dato  pct_sin_dato
# 0         genre_short            12           0          0.00
# 1       country_short             7           4          0.08
# 2  major_record_label             3         309          6.29
# 3                band             2           0          0.00
# 4       pronoun_short             4           0          0.00

# %%
# ============================================================
# Función general para evaluar combinaciones categóricas
# ============================================================

def evaluar_combinaciones_categoricas_vs_target(
    dataframe_base,
    variables_combinacion,
    target_shows,
    target_log1p_shows,
    mediana_global_shows,
    umbral_minimo_artistas_por_celda=20
):
    variables_combinacion = list(variables_combinacion)
    
    columnas_necesarias = variables_combinacion + [
        target_shows,
        target_log1p_shows
    ]
    
    columnas_faltantes = [
        columna
        for columna in columnas_necesarias
        if columna not in dataframe_base.columns
    ]
    
    if len(columnas_faltantes) > 0:
        raise ValueError(f"Columnas faltantes: {columnas_faltantes}")
    
    tabla_combinacion = (
        dataframe_base
        .groupby(variables_combinacion, dropna=False, observed=True)
        .agg(
            n_artistas=(target_shows, "size"),
            mediana_shows=(target_shows, "median"),
            p75_shows=(target_shows, lambda serie: serie.quantile(0.75)),
            pct_cero_shows=(target_shows, lambda serie: serie.eq(0).mean() * 100),
            mediana_log1p_shows=(target_log1p_shows, "median")
        )
        .reset_index()
    )
    
    tabla_combinacion = tabla_combinacion[
        tabla_combinacion["n_artistas"] >= umbral_minimo_artistas_por_celda
    ].copy()
    
    if mediana_global_shows == 0:
        tabla_combinacion["lift_mediana_vs_global"] = np.nan
    else:
        tabla_combinacion["lift_mediana_vs_global"] = (
            tabla_combinacion["mediana_shows"] / mediana_global_shows
        )
    
    tabla_combinacion["variables_combinadas"] = " + ".join(variables_combinacion)
    
    tabla_combinacion["combinacion"] = (
        tabla_combinacion[variables_combinacion]
        .astype(str)
        .agg(" | ".join, axis=1)
    )
    
    tabla_combinacion = tabla_combinacion.sort_values(
        by=["lift_mediana_vs_global", "n_artistas"],
        ascending=[False, False]
    ).reset_index(drop=True)
    
    tabla_combinacion["ranking_lift_descendente"] = np.arange(
        1,
        len(tabla_combinacion) + 1
    )
    
    tabla_combinacion["ranking_lift_ascendente"] = (
        tabla_combinacion["lift_mediana_vs_global"]
        .rank(method="first", ascending=True)
        .astype(int)
    )
    
    columnas_ordenadas = (
        ["variables_combinadas", "combinacion"]
        + variables_combinacion
        + [
            "n_artistas",
            "mediana_shows",
            "p75_shows",
            "pct_cero_shows",
            "mediana_log1p_shows",
            "lift_mediana_vs_global",
            "ranking_lift_descendente",
            "ranking_lift_ascendente"
        ]
    )
    
    return tabla_combinacion[columnas_ordenadas]

# %%
# ============================================================
# Evaluación de pares y tríos de variables categóricas
# ============================================================

lista_tablas_pares_categoricos = []
lista_tablas_trios_categoricos = []

for variables_par in combinations(variables_categoricas_candidatas, 2):
    tabla_par_actual = evaluar_combinaciones_categoricas_vs_target(
        dataframe_base=df_categoricas_target,
        variables_combinacion=variables_par,
        target_shows=target_shows,
        target_log1p_shows=target_log1p_shows,
        mediana_global_shows=mediana_global_shows,
        umbral_minimo_artistas_por_celda=umbral_minimo_artistas_por_celda
    )
    
    lista_tablas_pares_categoricos.append(tabla_par_actual)

for variables_trio in combinations(variables_categoricas_candidatas, 3):
    tabla_trio_actual = evaluar_combinaciones_categoricas_vs_target(
        dataframe_base=df_categoricas_target,
        variables_combinacion=variables_trio,
        target_shows=target_shows,
        target_log1p_shows=target_log1p_shows,
        mediana_global_shows=mediana_global_shows,
        umbral_minimo_artistas_por_celda=umbral_minimo_artistas_por_celda
    )
    
    lista_tablas_trios_categoricos.append(tabla_trio_actual)

tabla_pares_categoricos_vs_target = pd.concat(
    lista_tablas_pares_categoricos,
    ignore_index=True
)

tabla_trios_categoricos_vs_target = pd.concat(
    lista_tablas_trios_categoricos,
    ignore_index=True
)

tabla_pares_categoricos_vs_target = tabla_pares_categoricos_vs_target.sort_values(
    by=["lift_mediana_vs_global", "n_artistas"],
    ascending=[False, False]
).reset_index(drop=True)

tabla_trios_categoricos_vs_target = tabla_trios_categoricos_vs_target.sort_values(
    by=["lift_mediana_vs_global", "n_artistas"],
    ascending=[False, False]
).reset_index(drop=True)

print("Pares evaluados:", tabla_pares_categoricos_vs_target.shape)
print("Tríos evaluados:", tabla_trios_categoricos_vs_target.shape)
# Out:
# Pares evaluados: (188, 15)
# Tríos evaluados: (391, 15)

# %%
# ============================================================
# Rankings de combinaciones más altas y más bajas
# ============================================================

top_n_combinaciones = 25

tabla_top_pares_categoricos = tabla_pares_categoricos_vs_target.head(
    top_n_combinaciones
).copy()

tabla_bottom_pares_categoricos = (
    tabla_pares_categoricos_vs_target
    .sort_values(
        by=["lift_mediana_vs_global", "n_artistas"],
        ascending=[True, False]
    )
    .head(top_n_combinaciones)
    .copy()
)

tabla_top_trios_categoricos = tabla_trios_categoricos_vs_target.head(
    top_n_combinaciones
).copy()

tabla_bottom_trios_categoricos = (
    tabla_trios_categoricos_vs_target
    .sort_values(
        by=["lift_mediana_vs_global", "n_artistas"],
        ascending=[True, False]
    )
    .head(top_n_combinaciones)
    .copy()
)

tabla_top_pares_categoricos
# Out:
#                   variables_combinadas                          combinacion  \
# 0     genre_short + major_record_label                Country & folk | True
# 1          genre_short + pronoun_short              Country & folk | he/him
# 2                   genre_short + band               Country & folk | False
# 3          genre_short + country_short       Country & folk | North America
# 4     genre_short + major_record_label               Country & folk | False
# 5          genre_short + pronoun_short           Country & folk | they/them
# 6                   genre_short + band                Country & folk | True
# 7                   genre_short + band                  Rock & metal | True
# 8          genre_short + country_short         Rock & metal | North America
# 9          genre_short + pronoun_short             Country & folk | she/her
# 10         genre_short + pronoun_short             Rock & metal | they/them
# 11         genre_short + country_short  Alternative & indie | North America
# 12    genre_short + major_record_label                 Rock & metal | False
# 13    genre_short + major_record_label           Alternative & indie | True
# 14  country_short + major_record_label                 North America | True
# 15         genre_short + pronoun_short      Alternative & indie | they/them
# 16                  genre_short + band           Alternative & indie | True
# 17    genre_short + major_record_label                  Rock & metal | True
# 18         genre_short + pronoun_short         Alternative & indie | he/him
# 19    genre_short + major_record_label          Alternative & indie | False
# 20                  genre_short + band          Alternative & indie | False
# 21                country_short + band                 North America | True
# 22       country_short + pronoun_short            North America | they/them
# 23    genre_short + major_record_label             Regional mexicano | True
# 24         genre_short + pronoun_short        Alternative & indie | she/her
#
#             genre_short  country_short  n_artistas  mediana_shows  p75_shows  \
# 0        Country & folk            NaN          71           65.0       89.0
# 1        Country & folk            NaN         167           61.0       89.0
# 2        Country & folk            NaN         203           57.0       88.5
# 3        Country & folk  North America         236           56.0      88.25
# 4        Country & folk            NaN         177           50.0       87.0
# 5        Country & folk            NaN          61           50.0       82.0
# 6        Country & folk            NaN          62           48.0       81.5
# 7          Rock & metal            NaN         371           39.0       67.5
# 8          Rock & metal  North America         326           39.0      71.75
# 9        Country & folk            NaN          37           39.0       79.0
# 10         Rock & metal            NaN         359           38.0       67.0
# 11  Alternative & indie  North America         221           36.0       62.0
# 12         Rock & metal            NaN         349           35.0       67.0
# 13  Alternative & indie            NaN          97           33.0       64.0
# 14                  NaN  North America         544           32.0       61.0
# 15  Alternative & indie            NaN         190           31.5       62.0
# 16  Alternative & indie            NaN         199           31.0       62.0
# 17         Rock & metal            NaN         137           31.0       63.0
# 18  Alternative & indie            NaN          97           31.0       54.0
# 19  Alternative & indie            NaN         230           28.5       55.0
# 20  Alternative & indie            NaN         150           28.0       51.5
# 21                  NaN  North America         736           27.0       63.0
# 22                  NaN  North America         715           27.0       63.0
# 23    Regional mexicano            NaN          45           26.0       36.0
# 24  Alternative & indie            NaN          62           25.0      44.75
#
#     pct_cero_shows  mediana_log1p_shows  lift_mediana_vs_global  \
# 0         7.042254             4.189655                     5.0
# 1        13.173653             4.127134                4.692308
# 2        12.807882             4.060443                4.384615
# 3        13.135593             4.042897                4.307692
# 4        14.124294             3.931826                3.846154
# 5        13.114754             3.931826                3.846154
# 6        12.903226             3.890987                3.692308
# 7        19.137466             3.688879                     3.0
# 8        23.312883             3.688879                     3.0
# 9        10.810811             3.688879                     3.0
# 10       19.220056             3.663562                2.923077
# 11        4.072398             3.610918                2.769231
# 12       21.776504             3.583519                2.692308
# 13        4.123711             3.526361                2.538462
# 14       13.051471             3.496508                2.461538
# 15            10.0             3.481122                2.423077
# 16       10.050251             3.465736                2.384615
# 17       17.518248             3.465736                2.384615
# 18        5.154639             3.465736                2.384615
# 19        6.521739             3.384247                2.192308
# 20        5.333333             3.367296                2.153846
# 21       19.293478             3.332205                2.076923
# 22       19.300699             3.332205                2.076923
# 23            20.0             3.295837                     2.0
# 24        6.451613             3.258097                1.923077
#
#     ranking_lift_descendente  ranking_lift_ascendente major_record_label  \
# 0                          1                       30               True
# 1                          1                       31                NaN
# 2                          1                       23                NaN
# 3                          1                       39                NaN
# 4                          2                       29              False
# 5                          2                       30                NaN
# 6                          2                       22                NaN
# 7                          3                       21                NaN
# 8                          2                       38                NaN
# 9                          3                       29                NaN
# 10                         4                       28                NaN
# 11                         3                       37                NaN
# 12                         3                       28              False
# 13                         4                       27               True
# 14                         1                       17               True
# 15                         5                       27                NaN
# 16                         4                       20                NaN
# 17                         5                       26               True
# 18                         6                       26                NaN
# 19                         6                       25              False
# 20                         5                       19                NaN
# 21                         1                       11                NaN
# 22                         1                       17                NaN
# 23                         7                       24               True
# 24                         7                       25                NaN
#
#      band pronoun_short
# 0     NaN           NaN
# 1     NaN        he/him
# 2   False           NaN
# 3     NaN           NaN
# 4     NaN           NaN
# 5     NaN     they/them
# 6    True           NaN
# 7    True           NaN
# 8     NaN           NaN
# 9     NaN       she/her
# 10    NaN     they/them
# 11    NaN           NaN
# 12    NaN           NaN
# 13    NaN           NaN
# 14    NaN           NaN
# 15    NaN     they/them
# 16   True           NaN
# 17    NaN           NaN
# 18    NaN        he/him
# 19    NaN           NaN
# 20  False           NaN
# 21   True           NaN
# 22    NaN     they/them
# 23    NaN           NaN
# 24    NaN       she/her

# %%
# ============================================================
# Guardado de tablas del análisis categórico multivariado
# ============================================================

ruta_pares_completos = directorio_tablas_categoricas / "pares_categoricos_vs_n_shows_24_25.csv"
ruta_trios_completos = directorio_tablas_categoricas / "trios_categoricos_vs_n_shows_24_25.csv"
ruta_top_pares = directorio_tablas_categoricas / "top_pares_categoricos_vs_n_shows_24_25.csv"
ruta_bottom_pares = directorio_tablas_categoricas / "bottom_pares_categoricos_vs_n_shows_24_25.csv"
ruta_top_trios = directorio_tablas_categoricas / "top_trios_categoricos_vs_n_shows_24_25.csv"
ruta_bottom_trios = directorio_tablas_categoricas / "bottom_trios_categoricos_vs_n_shows_24_25.csv"
ruta_excel_resumen = directorio_tablas_categoricas / "resumen_lifts_categoricos_vs_n_shows_24_25.xlsx"

tabla_pares_categoricos_vs_target.to_csv(ruta_pares_completos, index=False)
tabla_trios_categoricos_vs_target.to_csv(ruta_trios_completos, index=False)
tabla_top_pares_categoricos.to_csv(ruta_top_pares, index=False)
tabla_bottom_pares_categoricos.to_csv(ruta_bottom_pares, index=False)
tabla_top_trios_categoricos.to_csv(ruta_top_trios, index=False)
tabla_bottom_trios_categoricos.to_csv(ruta_bottom_trios, index=False)

with pd.ExcelWriter(ruta_excel_resumen) as writer:
    tabla_top_pares_categoricos.to_excel(writer, sheet_name="top_pares", index=False)
    tabla_bottom_pares_categoricos.to_excel(writer, sheet_name="bottom_pares", index=False)
    tabla_top_trios_categoricos.to_excel(writer, sheet_name="top_trios", index=False)
    tabla_bottom_trios_categoricos.to_excel(writer, sheet_name="bottom_trios", index=False)
    tabla_pares_categoricos_vs_target.to_excel(writer, sheet_name="pares_completos", index=False)
    tabla_trios_categoricos_vs_target.to_excel(writer, sheet_name="trios_completos", index=False)

print("Tablas guardadas en:", directorio_tablas_categoricas)
# Out:
# Tablas guardadas en: tablas_categoricas

# %%
# ============================================================
# Sanity check final de resultados
# ============================================================

resumen_resultados_lifts = pd.DataFrame({
    "tabla": [
        "pares",
        "trios"
    ],
    "n_filas": [
        len(tabla_pares_categoricos_vs_target),
        len(tabla_trios_categoricos_vs_target)
    ],
    "n_combinaciones_variables": [
        tabla_pares_categoricos_vs_target["variables_combinadas"].nunique(),
        tabla_trios_categoricos_vs_target["variables_combinadas"].nunique()
    ],
    "lift_maximo": [
        tabla_pares_categoricos_vs_target["lift_mediana_vs_global"].max(),
        tabla_trios_categoricos_vs_target["lift_mediana_vs_global"].max()
    ],
    "lift_minimo": [
        tabla_pares_categoricos_vs_target["lift_mediana_vs_global"].min(),
        tabla_trios_categoricos_vs_target["lift_mediana_vs_global"].min()
    ],
    "umbral_minimo_artistas_por_celda": [
        umbral_minimo_artistas_por_celda,
        umbral_minimo_artistas_por_celda
    ]
})

resumen_resultados_lifts
# Out:
#    tabla  n_filas  n_combinaciones_variables  lift_maximo  lift_minimo  \
# 0  pares      188                         10     5.000000          0.0
# 1  trios      391                         10     5.230769          0.0
#
#    umbral_minimo_artistas_por_celda
# 0                                20
# 1                                20

# %%
tabla_top_trios_categoricos
# Out:
#                                  variables_combinadas  \
# 0    genre_short + country_short + major_record_label
# 1             genre_short + major_record_label + band
# 2    genre_short + major_record_label + pronoun_short
# 3         genre_short + country_short + pronoun_short
# 4                  genre_short + band + pronoun_short
# 5                  genre_short + country_short + band
# 6    genre_short + major_record_label + pronoun_short
# 7    genre_short + country_short + major_record_label
# 8                  genre_short + country_short + band
# 9         genre_short + country_short + pronoun_short
# 10            genre_short + major_record_label + band
# 11   genre_short + major_record_label + pronoun_short
# 12                 genre_short + band + pronoun_short
# 13            genre_short + major_record_label + band
# 14                 genre_short + country_short + band
# 15        genre_short + country_short + pronoun_short
# 16            genre_short + major_record_label + band
# 17   genre_short + country_short + major_record_label
# 18   genre_short + major_record_label + pronoun_short
# 19                 genre_short + band + pronoun_short
# 20   genre_short + country_short + major_record_label
# 21          country_short + major_record_label + band
# 22  country_short + major_record_label + pronoun_s...
# 23        genre_short + country_short + pronoun_short
# 24   genre_short + country_short + major_record_label
#
#                                      combinacion          genre_short  \
# 0          Country & folk | North America | True       Country & folk
# 1                  Country & folk | True | False       Country & folk
# 2                 Country & folk | True | he/him       Country & folk
# 3        Country & folk | North America | he/him       Country & folk
# 4                Country & folk | False | he/him       Country & folk
# 5         Country & folk | North America | False       Country & folk
# 6                Country & folk | False | he/him       Country & folk
# 7         Country & folk | North America | False       Country & folk
# 8          Country & folk | North America | True       Country & folk
# 9     Country & folk | North America | they/them       Country & folk
# 10                 Country & folk | False | True       Country & folk
# 11            Country & folk | False | they/them       Country & folk
# 12             Country & folk | True | they/them       Country & folk
# 13                Country & folk | False | False       Country & folk
# 14           Rock & metal | North America | True         Rock & metal
# 15      Rock & metal | North America | they/them         Rock & metal
# 16                   Rock & metal | False | True         Rock & metal
# 17           Rock & metal | North America | True         Rock & metal
# 18              Rock & metal | False | they/them         Rock & metal
# 19              Country & folk | False | she/her       Country & folk
# 20    Alternative & indie | North America | True  Alternative & indie
# 21                   North America | True | True                  NaN
# 22              North America | True | they/them                  NaN
# 23  Alternative & indie | North America | he/him  Alternative & indie
# 24          Rock & metal | North America | False         Rock & metal
#
#     country_short major_record_label  n_artistas  mediana_shows  p75_shows  \
# 0   North America               True          61           68.0       96.0
# 1             NaN               True          58           68.0      98.25
# 2             NaN               True          53           68.0       96.0
# 3   North America                NaN         148           62.0      89.25
# 4             NaN                NaN         167           61.0       89.0
# 5   North America                NaN         184           59.0       89.0
# 6             NaN              False         104           55.0      85.75
# 7   North America              False         159           52.0       87.5
# 8   North America                NaN          52           52.0       87.0
# 9   North America                NaN          51           52.0       87.0
# 10            NaN              False          46           51.0       87.0
# 11            NaN              False          46           51.0       87.0
# 12            NaN                NaN          61           50.0       82.0
# 13            NaN              False         131           49.0       85.0
# 14  North America                NaN         244           46.0      75.25
# 15  North America                NaN         238           45.5       74.0
# 16            NaN              False         244           44.0      73.25
# 17  North America               True          66           44.0       72.5
# 18            NaN              False         236           43.0      71.25
# 19            NaN                NaN          36           42.5      79.25
# 20  North America               True          52           41.5       72.5
# 21  North America               True         146           41.0      70.25
# 22  North America               True         140           41.0       71.0
# 23  North America                NaN          69           40.0       59.0
# 24  North America              False         249           39.0       74.0
#
#     pct_cero_shows  mediana_log1p_shows  lift_mediana_vs_global  \
# 0         4.918033             4.234107                5.230769
# 1         5.172414             4.234107                5.230769
# 2         5.660377             4.234107                5.230769
# 3        13.513514             4.143135                4.769231
# 4        13.173653             4.127134                4.692308
# 5        13.043478             4.094206                4.538462
# 6        16.346154             4.025352                4.230769
# 7         15.09434             3.970292                     4.0
# 8        13.461538             3.970292                     4.0
# 9         13.72549             3.970292                     4.0
# 10       10.869565             3.951059                3.923077
# 11       10.869565             3.951059                3.923077
# 12       13.114754             3.931826                3.846154
# 13       15.267176             3.912023                3.769231
# 14       18.852459             3.850148                3.538462
# 15       18.487395             3.839394                     3.5
# 16       18.442623             3.806416                3.384615
# 17       13.636364             3.806662                3.384615
# 18       18.220339             3.784190                3.307692
# 19       11.111111             3.769514                3.269231
# 20        1.923077             3.748881                3.192308
# 21       13.013699             3.737386                3.153846
# 22       12.857143             3.737386                3.153846
# 23        4.347826             3.713572                3.076923
# 24       24.497992             3.688879                     3.0
#
#     ranking_lift_descendente  ranking_lift_ascendente   band pronoun_short
# 0                          1                       55    NaN           NaN
# 1                          1                       46  False           NaN
# 2                          1                       55    NaN        he/him
# 3                          1                       59    NaN        he/him
# 4                          1                       31  False        he/him
# 5                          1                       50  False           NaN
# 6                          2                       54    NaN        he/him
# 7                          2                       54    NaN           NaN
# 8                          2                       49   True           NaN
# 9                          2                       58    NaN     they/them
# 10                         2                       45   True           NaN
# 11                         3                       53    NaN     they/them
# 12                         2                       30   True     they/them
# 13                         3                       44  False           NaN
# 14                         3                       48   True           NaN
# 15                         3                       57    NaN     they/them
# 16                         4                       43   True           NaN
# 17                         3                       53    NaN           NaN
# 18                         4                       52    NaN     they/them
# 19                         3                       29  False       she/her
# 20                         4                       52    NaN           NaN
# 21                         1                       27   True           NaN
# 22                         1                       38    NaN     they/them
# 23                         4                       56    NaN        he/him
# 24                         5                       51    NaN           NaN

# %%
tabla_bottom_pares_categoricos
# Out:
#                    variables_combinadas  \
# 181                  genre_short + band
# 182         genre_short + pronoun_short
# 183    genre_short + major_record_label
# 184         genre_short + country_short
# 185         genre_short + country_short
# 186    genre_short + major_record_label
# 187    genre_short + major_record_label
# 176           major_record_label + band
# 177  major_record_label + pronoun_short
# 178    genre_short + major_record_label
# 179    genre_short + major_record_label
# 180  country_short + major_record_label
# 175    genre_short + major_record_label
# 172  country_short + major_record_label
# 173    genre_short + major_record_label
# 174  country_short + major_record_label
# 169           major_record_label + band
# 170         genre_short + country_short
# 171  country_short + major_record_label
# 160                  genre_short + band
# 161    genre_short + major_record_label
# 162         genre_short + pronoun_short
# 163  major_record_label + pronoun_short
# 164         genre_short + country_short
# 165  major_record_label + pronoun_short
#
#                                    combinacion                genre_short  \
# 181          Jazz & blues & classical  | False  Jazz & blues & classical
# 182         Jazz & blues & classical  | he/him  Jazz & blues & classical
# 183          Jazz & blues & classical  | False  Jazz & blues & classical
# 184  Jazz & blues & classical  | North America  Jazz & blues & classical
# 185   Jazz & blues & classical  | Europe_sinGB  Jazz & blues & classical
# 186           Jazz & blues & classical  | True  Jazz & blues & classical
# 187                    Rock & metal | Sin dato               Rock & metal
# 176                            Sin dato | True                        NaN
# 177                       Sin dato | they/them                        NaN
# 178                             Pop | Sin dato                        Pop
# 179                  Hip-hop & trap | Sin dato             Hip-hop & trap
# 180                    Europe_sinGB | Sin dato                        NaN
# 175             Alternative & indie | Sin dato        Alternative & indie
# 172                   North America | Sin dato                        NaN
# 173              Electronic & dance | Sin dato         Electronic & dance
# 174                  Asia & Oceania | Sin dato                        NaN
# 169                           Sin dato | False                        NaN
# 170           Regional global | Asia & Oceania            Regional global
# 171                   Great Britain | Sin dato                        NaN
# 160                    Regional global | False            Regional global
# 161                    Regional global | False            Regional global
# 162                   Regional global | he/him            Regional global
# 163                          Sin dato | he/him                        NaN
# 164              Regional global | Africa & ME            Regional global
# 165                         Sin dato | she/her                        NaN
#
#       country_short  n_artistas  mediana_shows  p75_shows  pct_cero_shows  \
# 181             NaN         121            0.0        4.0       66.115702
# 182             NaN         112            0.0        2.5           68.75
# 183             NaN          79            0.0       13.0       58.227848
# 184   North America          62            0.0      27.75        54.83871
# 185    Europe_sinGB          54            0.0       0.75       74.074074
# 186             NaN          46            0.0        2.0       67.391304
# 187             NaN          28            0.0       5.75       53.571429
# 176             NaN         139            1.0       16.0        46.76259
# 177             NaN         137            1.0       15.0       47.445255
# 178             NaN          67            1.0       16.5       46.268657
# 179             NaN          39            1.0       27.5       33.333333
# 180    Europe_sinGB          31            1.0        4.5       48.387097
# 175             NaN          22            1.5       28.5       40.909091
# 172   North America         171            2.0       28.5       32.163743
# 173             NaN          41            2.0        5.0       29.268293
# 174  Asia & Oceania          23            2.0       20.0       34.782609
# 169             NaN         170            2.5      26.25       25.882353
# 170  Asia & Oceania          82            2.5       10.0       17.073171
# 171   Great Britain          42            2.5       11.0       42.857143
# 160             NaN         231            3.0       14.0        19.91342
# 161             NaN         188            3.0      14.25       20.212766
# 162             NaN         172            3.0       14.0       21.511628
# 163             NaN         122            3.0      27.75       28.688525
# 164     Africa & ME          65            3.0       13.0       18.461538
# 165             NaN          49            3.0       14.0       18.367347
#
#      mediana_log1p_shows  lift_mediana_vs_global  ranking_lift_descendente  \
# 181             0.000000                     0.0                        23
# 182             0.000000                     0.0                        31
# 183             0.000000                     0.0                        28
# 184             0.000000                     0.0                        38
# 185             0.000000                     0.0                        39
# 186             0.000000                     0.0                        29
# 187             0.000000                     0.0                        30
# 176             0.693147                0.076923                         6
# 177             0.693147                0.076923                         9
# 178             0.693147                0.076923                        26
# 179             0.693147                0.076923                        27
# 180             0.693147                0.076923                        17
# 175             0.895880                0.115385                        25
# 172             1.098612                0.153846                        15
# 173             1.098612                0.153846                        24
# 174             1.098612                0.153846                        16
# 169             1.242453                0.192308                         5
# 170             1.242453                0.192308                        37
# 171             1.242453                0.192308                        14
# 160             1.386294                0.230769                        22
# 161             1.386294                0.230769                        23
# 162             1.386294                0.230769                        30
# 163             1.386294                0.230769                         7
# 164             1.386294                0.230769                        34
# 165             1.386294                0.230769                         8
#
#      ranking_lift_ascendente major_record_label   band pronoun_short
# 181                        1                NaN  False           NaN
# 182                        1                NaN    NaN        he/him
# 183                        1              False    NaN           NaN
# 184                        1                NaN    NaN           NaN
# 185                        2                NaN    NaN           NaN
# 186                        2               True    NaN           NaN
# 187                        3           Sin dato    NaN           NaN
# 176                        1           Sin dato   True           NaN
# 177                        1           Sin dato    NaN     they/them
# 178                        4           Sin dato    NaN           NaN
# 179                        5           Sin dato    NaN           NaN
# 180                        1           Sin dato    NaN           NaN
# 175                        6           Sin dato    NaN           NaN
# 172                        2           Sin dato    NaN           NaN
# 173                        7           Sin dato    NaN           NaN
# 174                        3           Sin dato    NaN           NaN
# 169                        2           Sin dato  False           NaN
# 170                        3                NaN    NaN           NaN
# 171                        4           Sin dato    NaN           NaN
# 160                        2                NaN  False           NaN
# 161                        8              False    NaN           NaN
# 162                        2                NaN    NaN        he/him
# 163                        2           Sin dato    NaN        he/him
# 164                        4                NaN    NaN           NaN
# 165                        3           Sin dato    NaN       she/her

# %%
tabla_bottom_pares_categoricos
# Out:
#                    variables_combinadas  \
# 181                  genre_short + band
# 182         genre_short + pronoun_short
# 183    genre_short + major_record_label
# 184         genre_short + country_short
# 185         genre_short + country_short
# 186    genre_short + major_record_label
# 187    genre_short + major_record_label
# 176           major_record_label + band
# 177  major_record_label + pronoun_short
# 178    genre_short + major_record_label
# 179    genre_short + major_record_label
# 180  country_short + major_record_label
# 175    genre_short + major_record_label
# 172  country_short + major_record_label
# 173    genre_short + major_record_label
# 174  country_short + major_record_label
# 169           major_record_label + band
# 170         genre_short + country_short
# 171  country_short + major_record_label
# 160                  genre_short + band
# 161    genre_short + major_record_label
# 162         genre_short + pronoun_short
# 163  major_record_label + pronoun_short
# 164         genre_short + country_short
# 165  major_record_label + pronoun_short
#
#                                    combinacion                genre_short  \
# 181          Jazz & blues & classical  | False  Jazz & blues & classical
# 182         Jazz & blues & classical  | he/him  Jazz & blues & classical
# 183          Jazz & blues & classical  | False  Jazz & blues & classical
# 184  Jazz & blues & classical  | North America  Jazz & blues & classical
# 185   Jazz & blues & classical  | Europe_sinGB  Jazz & blues & classical
# 186           Jazz & blues & classical  | True  Jazz & blues & classical
# 187                    Rock & metal | Sin dato               Rock & metal
# 176                            Sin dato | True                        NaN
# 177                       Sin dato | they/them                        NaN
# 178                             Pop | Sin dato                        Pop
# 179                  Hip-hop & trap | Sin dato             Hip-hop & trap
# 180                    Europe_sinGB | Sin dato                        NaN
# 175             Alternative & indie | Sin dato        Alternative & indie
# 172                   North America | Sin dato                        NaN
# 173              Electronic & dance | Sin dato         Electronic & dance
# 174                  Asia & Oceania | Sin dato                        NaN
# 169                           Sin dato | False                        NaN
# 170           Regional global | Asia & Oceania            Regional global
# 171                   Great Britain | Sin dato                        NaN
# 160                    Regional global | False            Regional global
# 161                    Regional global | False            Regional global
# 162                   Regional global | he/him            Regional global
# 163                          Sin dato | he/him                        NaN
# 164              Regional global | Africa & ME            Regional global
# 165                         Sin dato | she/her                        NaN
#
#       country_short  n_artistas  mediana_shows  p75_shows  pct_cero_shows  \
# 181             NaN         121            0.0        4.0       66.115702
# 182             NaN         112            0.0        2.5           68.75
# 183             NaN          79            0.0       13.0       58.227848
# 184   North America          62            0.0      27.75        54.83871
# 185    Europe_sinGB          54            0.0       0.75       74.074074
# 186             NaN          46            0.0        2.0       67.391304
# 187             NaN          28            0.0       5.75       53.571429
# 176             NaN         139            1.0       16.0        46.76259
# 177             NaN         137            1.0       15.0       47.445255
# 178             NaN          67            1.0       16.5       46.268657
# 179             NaN          39            1.0       27.5       33.333333
# 180    Europe_sinGB          31            1.0        4.5       48.387097
# 175             NaN          22            1.5       28.5       40.909091
# 172   North America         171            2.0       28.5       32.163743
# 173             NaN          41            2.0        5.0       29.268293
# 174  Asia & Oceania          23            2.0       20.0       34.782609
# 169             NaN         170            2.5      26.25       25.882353
# 170  Asia & Oceania          82            2.5       10.0       17.073171
# 171   Great Britain          42            2.5       11.0       42.857143
# 160             NaN         231            3.0       14.0        19.91342
# 161             NaN         188            3.0      14.25       20.212766
# 162             NaN         172            3.0       14.0       21.511628
# 163             NaN         122            3.0      27.75       28.688525
# 164     Africa & ME          65            3.0       13.0       18.461538
# 165             NaN          49            3.0       14.0       18.367347
#
#      mediana_log1p_shows  lift_mediana_vs_global  ranking_lift_descendente  \
# 181             0.000000                     0.0                        23
# 182             0.000000                     0.0                        31
# 183             0.000000                     0.0                        28
# 184             0.000000                     0.0                        38
# 185             0.000000                     0.0                        39
# 186             0.000000                     0.0                        29
# 187             0.000000                     0.0                        30
# 176             0.693147                0.076923                         6
# 177             0.693147                0.076923                         9
# 178             0.693147                0.076923                        26
# 179             0.693147                0.076923                        27
# 180             0.693147                0.076923                        17
# 175             0.895880                0.115385                        25
# 172             1.098612                0.153846                        15
# 173             1.098612                0.153846                        24
# 174             1.098612                0.153846                        16
# 169             1.242453                0.192308                         5
# 170             1.242453                0.192308                        37
# 171             1.242453                0.192308                        14
# 160             1.386294                0.230769                        22
# 161             1.386294                0.230769                        23
# 162             1.386294                0.230769                        30
# 163             1.386294                0.230769                         7
# 164             1.386294                0.230769                        34
# 165             1.386294                0.230769                         8
#
#      ranking_lift_ascendente major_record_label   band pronoun_short
# 181                        1                NaN  False           NaN
# 182                        1                NaN    NaN        he/him
# 183                        1              False    NaN           NaN
# 184                        1                NaN    NaN           NaN
# 185                        2                NaN    NaN           NaN
# 186                        2               True    NaN           NaN
# 187                        3           Sin dato    NaN           NaN
# 176                        1           Sin dato   True           NaN
# 177                        1           Sin dato    NaN     they/them
# 178                        4           Sin dato    NaN           NaN
# 179                        5           Sin dato    NaN           NaN
# 180                        1           Sin dato    NaN           NaN
# 175                        6           Sin dato    NaN           NaN
# 172                        2           Sin dato    NaN           NaN
# 173                        7           Sin dato    NaN           NaN
# 174                        3           Sin dato    NaN           NaN
# 169                        2           Sin dato  False           NaN
# 170                        3                NaN    NaN           NaN
# 171                        4           Sin dato    NaN           NaN
# 160                        2                NaN  False           NaN
# 161                        8              False    NaN           NaN
# 162                        2                NaN    NaN        he/him
# 163                        2           Sin dato    NaN        he/him
# 164                        4                NaN    NaN           NaN
# 165                        3           Sin dato    NaN       she/her

# %%
tabla_bottom_trios_categoricos
# Out:
#                                   variables_combinadas  \
# 373                 genre_short + band + pronoun_short
# 374            genre_short + major_record_label + band
# 375   genre_short + major_record_label + pronoun_short
# 376                 genre_short + country_short + band
# 377                 genre_short + country_short + band
# 378        genre_short + country_short + pronoun_short
# 379        genre_short + country_short + pronoun_short
# 380            genre_short + major_record_label + band
# 381   genre_short + major_record_label + pronoun_short
# 382            genre_short + major_record_label + band
# 383   genre_short + major_record_label + pronoun_short
# 384   genre_short + country_short + major_record_label
# 385   genre_short + country_short + major_record_label
# 386          country_short + major_record_label + band
# 387  country_short + major_record_label + pronoun_s...
# 388   genre_short + country_short + major_record_label
# 389          country_short + major_record_label + band
# 390  country_short + major_record_label + pronoun_s...
# 371            genre_short + major_record_label + band
# 372   genre_short + major_record_label + pronoun_short
# 368          major_record_label + band + pronoun_short
# 369   genre_short + country_short + major_record_label
# 370   genre_short + country_short + major_record_label
# 355   genre_short + major_record_label + pronoun_short
# 356          country_short + major_record_label + band
#
#                                            combinacion  \
# 373         Jazz & blues & classical  | False | he/him
# 374          Jazz & blues & classical  | False | False
# 375         Jazz & blues & classical  | False | he/him
# 376  Jazz & blues & classical  | North America | False
# 377   Jazz & blues & classical  | Europe_sinGB | False
# 378  Jazz & blues & classical  | Europe_sinGB | he/him
# 379  Jazz & blues & classical  | North America | he...
# 380           Jazz & blues & classical  | True | False
# 381          Jazz & blues & classical  | True | he/him
# 382                              Pop | Sin dato | True
# 383                         Pop | Sin dato | they/them
# 384  Jazz & blues & classical  | North America | False
# 385    Jazz & blues & classical  | Europe_sinGB | True
# 386                    Great Britain | Sin dato | True
# 387               Great Britain | Sin dato | they/them
# 388   Jazz & blues & classical  | Europe_sinGB | False
# 389                     Europe_sinGB | Sin dato | True
# 390                Europe_sinGB | Sin dato | they/them
# 371                     Rock & metal | Sin dato | True
# 372                Rock & metal | Sin dato | they/them
# 368                        Sin dato | True | they/them
# 369                     Pop | North America | Sin dato
# 370          Hip-hop & trap | North America | Sin dato
# 355                   Regional global | False | he/him
# 356                   North America | Sin dato | False
#
#                    genre_short  country_short major_record_label  n_artistas  \
# 373  Jazz & blues & classical             NaN                NaN         110
# 374  Jazz & blues & classical             NaN              False          68
# 375  Jazz & blues & classical             NaN              False          62
# 376  Jazz & blues & classical   North America                NaN          53
# 377  Jazz & blues & classical    Europe_sinGB                NaN          51
# 378  Jazz & blues & classical    Europe_sinGB                NaN          49
# 379  Jazz & blues & classical   North America                NaN          49
# 380  Jazz & blues & classical             NaN               True          44
# 381  Jazz & blues & classical             NaN               True          42
# 382                        Pop            NaN           Sin dato          41
# 383                        Pop            NaN           Sin dato          40
# 384  Jazz & blues & classical   North America              False          39
# 385  Jazz & blues & classical    Europe_sinGB               True          27
# 386                        NaN  Great Britain           Sin dato          26
# 387                        NaN  Great Britain           Sin dato          26
# 388  Jazz & blues & classical    Europe_sinGB              False          25
# 389                        NaN   Europe_sinGB           Sin dato          21
# 390                        NaN   Europe_sinGB           Sin dato          21
# 371               Rock & metal            NaN           Sin dato          22
# 372               Rock & metal            NaN           Sin dato          22
# 368                        NaN            NaN           Sin dato         137
# 369                        Pop  North America           Sin dato          35
# 370             Hip-hop & trap  North America           Sin dato          34
# 355            Regional global            NaN              False         121
# 356                        NaN  North America           Sin dato         106
#
#      mediana_shows  p75_shows  pct_cero_shows  mediana_log1p_shows  \
# 373            0.0       1.75            70.0             0.000000
# 374            0.0        1.5       67.647059             0.000000
# 375            0.0        1.0       69.354839             0.000000
# 376            0.0       10.0       62.264151             0.000000
# 377            0.0        0.0       78.431373             0.000000
# 378            0.0        0.0       79.591837             0.000000
# 379            0.0        8.0       63.265306             0.000000
# 380            0.0        2.5       68.181818             0.000000
# 381            0.0       1.75       71.428571             0.000000
# 382            0.0        7.0       53.658537             0.000000
# 383            0.0        7.0            55.0             0.000000
# 384            0.0       33.0       56.410256             0.000000
# 385            0.0        0.0       77.777778             0.000000
# 386            0.0        5.5       57.692308             0.000000
# 387            0.0        5.5       57.692308             0.000000
# 388            0.0        1.0            72.0             0.000000
# 389            0.0        4.0       57.142857             0.000000
# 390            0.0        4.0       57.142857             0.000000
# 371            0.5      13.25            50.0             0.346574
# 372            0.5      13.25            50.0             0.346574
# 368            1.0       15.0       47.445255             0.693147
# 369            1.0        8.0       45.714286             0.693147
# 370            1.0      25.25       38.235294             0.693147
# 355            2.0       12.0        22.31405             1.098612
# 356            2.0       30.5       25.471698             1.098612
#
#      lift_mediana_vs_global  ranking_lift_descendente  \
# 373                     0.0                        31
# 374                     0.0                        44
# 375                     0.0                        53
# 376                     0.0                        49
# 377                     0.0                        50
# 378                     0.0                        58
# 379                     0.0                        59
# 380                     0.0                        45
# 381                     0.0                        54
# 382                     0.0                        46
# 383                     0.0                        55
# 384                     0.0                        53
# 385                     0.0                        54
# 386                     0.0                        26
# 387                     0.0                        37
# 388                     0.0                        55
# 389                     0.0                        27
# 390                     0.0                        38
# 371                0.038462                        43
# 372                0.038462                        52
# 368                0.076923                        11
# 369                0.076923                        51
# 370                0.076923                        52
# 355                0.153846                        49
# 356                0.153846                        25
#
#      ranking_lift_ascendente   band pronoun_short
# 373                        1  False        he/him
# 374                        1  False           NaN
# 375                        1    NaN        he/him
# 376                        1  False           NaN
# 377                        2  False           NaN
# 378                        1    NaN        he/him
# 379                        2    NaN        he/him
# 380                        2  False           NaN
# 381                        2    NaN        he/him
# 382                        3   True           NaN
# 383                        3    NaN     they/them
# 384                        1    NaN           NaN
# 385                        2    NaN           NaN
# 386                        1   True           NaN
# 387                        1    NaN     they/them
# 388                        3    NaN           NaN
# 389                        2   True           NaN
# 390                        2    NaN     they/them
# 371                        4   True           NaN
# 372                        4    NaN     they/them
# 368                        1   True     they/them
# 369                        4    NaN           NaN
# 370                        5    NaN           NaN
# 355                        5    NaN        he/him
# 356                        3  False           NaN

# %% [markdown]
# # graficos

# %%
# ============================================================
# Directorio de gráficos para análisis categórico multivariado
# ============================================================

directorio_graficos_categoricos = pathlib.Path("graficos_categoricos")
directorio_graficos_categoricos.mkdir(exist_ok=True)

print("Directorio de gráficos:", directorio_graficos_categoricos)
# Out:
# Directorio de gráficos: graficos_categoricos

# %%
# ============================================================
# Figura editorial de combinaciones categóricas top y bottom
# ============================================================

cantidad_top_combinaciones_grafico = 7
cantidad_bottom_combinaciones_grafico = 5

tabla_top_trios_para_grafico = tabla_trios_categoricos_vs_target.head(
    cantidad_top_combinaciones_grafico
).copy()

tabla_bottom_trios_para_grafico = (
    tabla_trios_categoricos_vs_target
    .sort_values(
        by=["lift_mediana_vs_global", "n_artistas"],
        ascending=[True, False]
    )
    .head(cantidad_bottom_combinaciones_grafico)
    .copy()
)

tabla_ranking_editorial_lifts = pd.concat(
    [
        tabla_top_trios_para_grafico.assign(tipo_hallazgo="Top lift"),
        tabla_bottom_trios_para_grafico.assign(tipo_hallazgo="Bottom lift")
    ],
    ignore_index=True
)


# ============================================================
# Etiquetas legibles según la variable categórica original
# ============================================================

def formatear_valor_categorico_para_grafico(nombre_variable, valor_variable):
    valor_como_texto = str(valor_variable)
    
    if nombre_variable == "major_record_label":
        if valor_variable is True or valor_como_texto == "True":
            return "major_record_label"
        elif valor_variable is False or valor_como_texto == "False":
            return "independent_label"
    
    if nombre_variable == "band":
        if valor_variable is True or valor_como_texto == "True":
            return "Band"
        elif valor_variable is False or valor_como_texto == "False":
            return "Solista"
    
    return valor_como_texto


def construir_etiqueta_combinacion_desde_columnas(fila):
    variables_de_la_combinacion = [
        variable.strip()
        for variable in fila["variables_combinadas"].split("+")
    ]
    
    valores_formateados = []
    
    for variable_actual in variables_de_la_combinacion:
        valor_actual = fila[variable_actual]
        
        valor_formateado = formatear_valor_categorico_para_grafico(
            nombre_variable=variable_actual,
            valor_variable=valor_actual
        )
        
        valores_formateados.append(valor_formateado)
    
    return " | ".join(valores_formateados)


tabla_ranking_editorial_lifts["combinacion_grafico"] = (
    tabla_ranking_editorial_lifts
    .apply(construir_etiqueta_combinacion_desde_columnas, axis=1)
)

tabla_ranking_editorial_lifts["etiqueta_grafico"] = (
    tabla_ranking_editorial_lifts["combinacion_grafico"]
    + "\n"
    + "n="
    + tabla_ranking_editorial_lifts["n_artistas"].astype(str)
    + " | mediana="
    + tabla_ranking_editorial_lifts["mediana_shows"].round(1).astype(str)
)

tabla_ranking_editorial_lifts = tabla_ranking_editorial_lifts.sort_values(
    by="lift_mediana_vs_global",
    ascending=True
).reset_index(drop=True)


# ============================================================
# Construcción del gráfico
# ============================================================

fig, ax = plt.subplots(figsize=(11, 8))

tamanios_puntos = (
    tabla_ranking_editorial_lifts["n_artistas"] /
    tabla_ranking_editorial_lifts["n_artistas"].max()
) * 900 + 120

scatter = ax.scatter(
    tabla_ranking_editorial_lifts["lift_mediana_vs_global"],
    tabla_ranking_editorial_lifts["etiqueta_grafico"],
    s=tamanios_puntos,
    c=tabla_ranking_editorial_lifts["pct_cero_shows"],
    cmap="magma_r",
    alpha=0.85,
    edgecolor="#2F2F2F",
    linewidth=0.8
)

ax.axvline(
    x=1,
    color="#2F2F2F",
    linestyle="--",
    linewidth=1,
    alpha=0.7
)

ax.set_title(
    'Lift medianas shows según genre, territorio, record label, banda y género',
    fontsize=15,
    fontweight="bold",
    loc="left",
    pad=34
)

ax.text(
    0,
    1.025,
    "Top 7000 artistas. Lifts máximos y mínimos. Shows 24_25",
    transform=ax.transAxes,
    fontsize=11,
    color="#666666",
    ha="left",
    va="bottom"
)

ax.set_xlabel("Lift de la mediana de shows vs mediana global", fontsize=11)
ax.set_ylabel("")

ax.grid(axis="x", alpha=0.25)

barra_color = plt.colorbar(scatter, ax=ax)
barra_color.set_label("% de artistas con 0 shows", fontsize=10)

plt.tight_layout()

ruta_grafico_ranking_editorial = (
    directorio_salidas_proyecto /
    "ranking_editorial_lifts_top_bottom_trios.png"
)

plt.savefig(
    ruta_grafico_ranking_editorial,
    dpi=300,
    bbox_inches="tight"
)

plt.show()

print("Gráfico guardado en:", ruta_grafico_ranking_editorial)
# Out:
# Gráfico guardado en: C:\Users\Silvana\Documents\Maestria_Exactas\taller_tesis_1\music_industry_social_live_code\graficos\ranking_editorial_lifts_top_bottom_trios.png

# %%
# ============================================================
# Bubble heatmap de genre_short x country_short
# ============================================================

tabla_genero_region_lifts = tabla_pares_categoricos_vs_target[
    tabla_pares_categoricos_vs_target["variables_combinadas"] == "genre_short + country_short"
].copy()

orden_generos_por_lift_maximo = (
    tabla_genero_region_lifts
    .groupby("genre_short")["lift_mediana_vs_global"]
    .max()
    .sort_values(ascending=True)
    .index
    .tolist()
)

orden_regiones_por_lift_maximo = (
    tabla_genero_region_lifts
    .groupby("country_short")["lift_mediana_vs_global"]
    .max()
    .sort_values(ascending=False)
    .index
    .tolist()
)

tabla_genero_region_lifts["genre_short"] = pd.Categorical(
    tabla_genero_region_lifts["genre_short"],
    categories=orden_generos_por_lift_maximo,
    ordered=True
)

tabla_genero_region_lifts["country_short"] = pd.Categorical(
    tabla_genero_region_lifts["country_short"],
    categories=orden_regiones_por_lift_maximo,
    ordered=True
)

tabla_genero_region_lifts = tabla_genero_region_lifts.sort_values(
    by=["genre_short", "country_short"]
).reset_index(drop=True)

fig, ax = plt.subplots(figsize=(12, 8))

tamanios_burbujas = (
    tabla_genero_region_lifts["n_artistas"] /
    tabla_genero_region_lifts["n_artistas"].max()
) * 1400 + 80

scatter = ax.scatter(
    tabla_genero_region_lifts["country_short"],
    tabla_genero_region_lifts["genre_short"],
    s=tamanios_burbujas,
    c=tabla_genero_region_lifts["lift_mediana_vs_global"],
    cmap="viridis",
    alpha=0.82,
    edgecolor="#2F2F2F",
    linewidth=0.7
)

for _, fila in tabla_genero_region_lifts.iterrows():
    ax.text(
        fila["country_short"],
        fila["genre_short"],
        f"{fila['mediana_shows']:.0f}",
        ha="center",
        va="center",
        fontsize=8,
        color="white",
        fontweight="bold"
    )

ax.axvline(
    x=-0.5,
    color="white",
    linewidth=0
)

ax.set_title(
    'Lift mediana shows según genre y territorio',
    fontsize=16,
    fontweight="bold",
    loc="left",
    pad=34
)

ax.text(
    0,
    1.025,
    "Top 7000 artistas. Shows 24_25. Nros = mediana. Tamaño burbuja: observaciones",
    transform=ax.transAxes,
    fontsize=11,
    color="#666666",
    ha="left",
    va="bottom"
)



ax.set_xlabel('"country_short"', fontsize=11)
ax.set_ylabel('"genre_short"', fontsize=11)

ax.tick_params(axis="x", rotation=35)
ax.grid(alpha=0.18)

barra_color = plt.colorbar(scatter, ax=ax)
barra_color.set_label("Lift de mediana de shows vs mediana global", fontsize=10)

plt.tight_layout()

ruta_grafico_bubble_heatmap_genero_region = (
    directorio_salidas_proyecto /
    "bubble_heatmap_genre_short_country_short_lifts.png"
)

plt.savefig(
    ruta_grafico_bubble_heatmap_genero_region,
    dpi=300,
    bbox_inches="tight"
)

plt.show()

print("Gráfico guardado en:", ruta_grafico_bubble_heatmap_genero_region)
# Out:
# Gráfico guardado en: C:\Users\Silvana\Documents\Maestria_Exactas\taller_tesis_1\music_industry_social_live_code\graficos\bubble_heatmap_genre_short_country_short_lifts.png

# %%
# ============================================================
# Sanity check de tablas usadas en gráficos
# ============================================================

sanity_graficos_categoricos = pd.DataFrame({
    "grafico": [
        "ranking_editorial_top_bottom_trios",
        "bubble_heatmap_genre_short_country_short"
    ],
    "n_filas_usadas": [
        len(tabla_ranking_editorial_lifts),
        len(tabla_genero_region_lifts)
    ],
    "lift_minimo": [
        tabla_ranking_editorial_lifts["lift_mediana_vs_global"].min(),
        tabla_genero_region_lifts["lift_mediana_vs_global"].min()
    ],
    "lift_maximo": [
        tabla_ranking_editorial_lifts["lift_mediana_vs_global"].max(),
        tabla_genero_region_lifts["lift_mediana_vs_global"].max()
    ],
    "n_minimo_artistas": [
        tabla_ranking_editorial_lifts["n_artistas"].min(),
        tabla_genero_region_lifts["n_artistas"].min()
    ]
})

sanity_graficos_categoricos
# Out:
#                                     grafico  n_filas_usadas  lift_minimo  \
# 0        ranking_editorial_top_bottom_trios              12          0.0
# 1  bubble_heatmap_genre_short_country_short              39          0.0
#
#    lift_maximo  n_minimo_artistas
# 0     5.230769                 51
# 1     4.307692                 20
